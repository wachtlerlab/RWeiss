# %%
import csv

ch1 = csv.reader(open("/home/weiss/oszi/ALL0006/F0006CH1.CSV", "rb"), delimiter=',')
ch2 = csv.reader(open("/home/weiss/oszi/ALL0006/F0006CH2.CSV", "rb"), delimiter=',')
t = zeros((2500))
trig = zeros((2500))
x = zeros((2500))
i = 0
for row in ch1:
    t[i] = row[3]
    x[i] = row[4]
    i += 1

i = 0
for row in ch2:
    trig[i] = row[4]
    i += 1
    
f = figure(figsize=(10,4))
gs = GridSpec(3, 3)
a1 = subplot(gs[:2, :])
a1.plot(t, x, linewidth=2, label='Signal')
a1.set_ylabel('U [V]', fontsize=15)
a1.set_yticks([0,5])
a1.set_xticklabels([])
a1.legend(loc='lower right', fontsize=15)
#plt.xlim(0,.5)
plt.xlim(-.015,.015)
plt.yticks(fontsize=15)

a2 = subplot(gs[2, :])
a2.plot(t, trig, linewidth=2, color='g', label='Trigger')
a2.set_xlabel('t [s]', fontsize=15)
a2.set_ylabel('U [V]', fontsize=15)
a2.set_yticks([0,5])
a2.set_ybound(0,6)
a2.set_xticks([-.01,0, .01])
a2.legend(loc='lower right', fontsize=15)
#plt.xlim(0, .5)
plt.xlim(-.015,.015)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
tight_layout()

#plt.savefig("/home/weiss/ba/figures/oszi1.pdf")
