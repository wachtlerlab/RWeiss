# %%
import csv

data = csv.reader(open("/home/weiss/oszi/ALL0010/F0010CH1.CSV", "rb"), delimiter=',')
t = zeros((2500))
x = zeros((2500))
i = 0
for row in data:
    t[i] = row[3]
    x[i] = row[4]
    i += 1
    
plot(t,x)
