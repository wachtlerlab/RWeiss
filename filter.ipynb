# %%
x = arange(0,.12,.001)
y = .005*(((x**3)/(.005**4))*exp(-x/.005)-((x**3)/(.01**4))*exp(-x/.01))
Y = fft.fft(y, 1000)/21.6
freq = fft.fftfreq(1000, .001)

f, p = plt.subplots(1, 2, figsize=(10,4), sharey=True)
p[0].plot(x, y, linewidth=2)
p[0].set_xlabel('t [s]', fontsize=15)
p[0].set_ylabel('Amplitude', fontsize=15)
p[0].grid()

p[0].tick_params(labelsize=15)

p[1].plot(freq[:200], abs(Y[:200]), linewidth=2)
p[1].set_xlabel('Frequenz [Hz]', fontsize=15)
p[1].grid()

plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

plt.tight_layout()

#plt.savefig("/Users/robinweiss/Documents/RWeiss/figures/filter.pdf")
